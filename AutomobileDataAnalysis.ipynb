# %% [markdown]
# # Data Analysis of Automobile data

# %% [markdown]
# ### Importing useful libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Reading the dataset

# %%
data = pd.read_csv('/Users/manis/Downloads/Automobile_data.csv')
data.head(10)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
print('The given dataset has {} rows and {} columns...'.format(data.shape[0], data.shape[1]))
# Out:
# The given dataset has 205 rows and 26 columns...

# %% [markdown]
# ### Lets see if there is missing value in dataset

# %%
data.isnull().mean()
# Out:
# symboling            0.0
# normalized-losses    0.0
# make                 0.0
# fuel-type            0.0
# aspiration           0.0
# num-of-doors         0.0
# body-style           0.0
# drive-wheels         0.0
# engine-location      0.0
# wheel-base           0.0
# length               0.0
# width                0.0
# height               0.0
# curb-weight          0.0
# engine-type          0.0
# num-of-cylinders     0.0
# engine-size          0.0
# fuel-system          0.0
# bore                 0.0
# stroke               0.0
# compression-ratio    0.0
# horsepower           0.0
# peak-rpm             0.0
# city-mpg             0.0
# highway-mpg          0.0
# price                0.0
# dtype: float64

# %% [markdown]
# ### It is showing no Nan values because missing values are not in the form of Nan as we can notice there are '?' symbols. Lets see how can we find

# %%
pd.pandas.set_option('display.max_columns', None)
data.head(50)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
df = pd.read_csv('/Users/manis/Downloads/Automobile_data.csv', na_values='?')  
df.head(10)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
# 5          2                NaN         audi       gas        std
# 6          1              158.0         audi       gas        std
# 7          1                NaN         audi       gas        std
# 8          1              158.0         audi       gas      turbo
# 9          0                NaN         audi       gas      turbo
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# ...

# %%
df.isnull().mean()
# Out:
# symboling            0.000000
# normalized-losses    0.200000
# make                 0.000000
# fuel-type            0.000000
# aspiration           0.000000
# num-of-doors         0.009756
# body-style           0.000000
# drive-wheels         0.000000
# engine-location      0.000000
# wheel-base           0.000000
# length               0.000000
# width                0.000000
# height               0.000000
# curb-weight          0.000000
# engine-type          0.000000
# num-of-cylinders     0.000000
# engine-size          0.000000
# fuel-system          0.000000
# bore                 0.019512
# stroke               0.019512
# compression-ratio    0.000000
# horsepower           0.009756
# peak-rpm             0.009756
# city-mpg             0.000000
# highway-mpg          0.000000
# price                0.019512
# dtype: float64

# %% [markdown]
# ### So we can see there are some missing values
# ### lets see 5 number summary, mean, std, etc... of dataset

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  205.000000   205.000000   205.000000  201.000000  201.000000
# mean    53.724878  2555.565854   126.907317    3.329751    3.255423
# std      2.443522   520.680204    41.642693    0.273539    0.316717
# ...

# %% [markdown]
# ### Now lets find out numerical features in the dataset

# %%
num_feature = [feature for feature in df.columns if df[feature].dtype!='O']
print('There are {} numerical features..'.format(len(num_feature)))
num_feature
# Out:
# There are 16 numerical features..
# ['symboling',
#  'normalized-losses',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-size',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %%
df[num_feature].head()
# Out:
#    symboling  normalized-losses  wheel-base  length  width  height  \
# 0          3                NaN        88.6   168.8   64.1    48.8
# 1          3                NaN        88.6   168.8   64.1    48.8
# 2          1                NaN        94.5   171.2   65.5    52.4
# 3          2              164.0        99.8   176.6   66.2    54.3
# 4          2              164.0        99.4   176.6   66.4    54.3
#
#    curb-weight  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0         2548          130  3.47    2.68                9.0       111.0
# 1         2548          130  3.47    2.68                9.0       111.0
# 2         2823          152  2.68    3.47                9.0       154.0
# 3         2337          109  3.19    3.40               10.0       102.0
# 4         2824          136  3.19    3.40                8.0       115.0
#
#    peak-rpm  city-mpg  highway-mpg    price
# 0    5000.0        21           27  13495.0
# ...

# %% [markdown]
# ### Now lets find out if there are any discrete feature in these numerical features

# %%
disc_feature = [feature for feature in num_feature if len(df[feature].unique())<20]
print('There are {} discrete features..'.format(len(disc_feature)))
disc_feature
# Out:
# There are 1 discrete features..
# ['symboling']

# %%
# there is only one discrete feature

df['symboling'].unique()
# Out:
# array([ 3,  1,  2,  0, -1, -2], dtype=int64)

# %%
df.groupby('symboling')['price'].mean().plot.bar(color='r')
plt.title('symboling')
plt.xlabel('symboling')
plt.ylabel('price')
plt.show()

# %% [markdown]
# ### Now lets analyse continuous features

# %%
continuous_feature = [feature for feature in num_feature if feature not in disc_feature]
print('There are {} continuous features..'.format(len(continuous_feature)))
continuous_feature
# Out:
# There are 15 continuous features..
# ['normalized-losses',
#  'wheel-base',
#  'length',
#  'width',
#  'height',
#  'curb-weight',
#  'engine-size',
#  'bore',
#  'stroke',
#  'compression-ratio',
#  'horsepower',
#  'peak-rpm',
#  'city-mpg',
#  'highway-mpg',
#  'price']

# %% [markdown]
# ### lets see the distribution of continuous features

# %%
for feature in continuous_feature:
    sns.distplot(df[feature], bins=30, color='m')
    plt.xlabel(feature)
    plt.title('Distribution of '+feature)
    plt.show()
# Out:
# C:\Users\manis\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\manis\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
for feature in continuous_feature:
    d = df.copy()
    d[feature] = np.log(d[feature])
    sns.distplot(d[feature], bins=30, color='m')
    plt.xlabel(feature)
    plt.title('Distribution of '+feature)
    plt.show()
# Out:
# C:\Users\manis\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\manis\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Working with outliers

# %%
for feature in continuous_feature:
    df.boxplot(column=feature)
    plt.title(feature)
    plt.show()

# %%
for feature in continuous_feature:
    l = np.mean(df[feature])-2*np.std(df[feature])
    h = np.mean(df[feature])+2*np.std(df[feature])
    print('sd Range of ', feature, ': ', np.round(l,4), ' to ', np.round(h,4))
    outliers = []
    values = []
    for val in df[feature].values:
        if val>h or val<l:
            outliers.append(1)
            values.append(val)
        else:
            outliers.append(0)
    d = df.copy()
    d[feature+'_sd_outliers'] = outliers
    print('There are {} sd outliers in '.format(len(values)), feature)
    print(values)
    sns.distplot(df[feature], bins=25, color='m')
    #plt.axvline(x=minimum, ymin=0, ymax=1, fillstyle='left', color='m')
    #plt.axvline(x=maximum, ymin=0, ymax=1, fillstyle='right', color='m')
    plt.axvspan(h, df[feature].max(), color='y')
    plt.axvspan(df[feature].min(), l, color='y')
    plt.title(feature+' with outliers')
    plt.xlabel(feature)
    plt.show()
# Out:
# sd Range of  normalized-losses :  51.3321  to  192.6679
# There are 6 sd outliers in  normalized-losses
# [194.0, 194.0, 231.0, 197.0, 197.0, 256.0]
# C:\Users\manis\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# sd Range of  wheel-base :  86.7424  to  110.7707
# There are 12 sd outliers in  wheel-base
# [86.6, 86.6, 113.0, 113.0, 115.6, 115.6, 120.9, 112.0, 114.2, 114.2, 114.2, 114.2]
# ...

# %%
for feature in continuous_feature:
    q3 = df[feature].quantile(0.75)
    q1 = df[feature].quantile(0.25)
    iqr = q3-q1
    l = q1-1.5*iqr
    h = q3+1.5*iqr
    print('sd Range of ', feature, ': ', np.round(l,4), ' to ', np.round(h,4))
    outliers = []
    values = []
    for val in df[feature].values:
        if val>h or val<l:
            outliers.append(1)
            values.append(val)
        else:
            outliers.append(0)
    d = df.copy()
    d[feature+'_sd_outliers'] = outliers
    print('There are {} sd outliers in '.format(len(values)), feature)
    print(values)
    sns.distplot(df[feature], bins=25, color='m')
    #plt.axvline(x=minimum, ymin=0, ymax=1, fillstyle='left', color='m')
    #plt.axvline(x=maximum, ymin=0, ymax=1, fillstyle='right', color='m')
    plt.axvspan(h, df[feature].max(), color='y')
    plt.axvspan(df[feature].min(), l, color='y')
    plt.title(feature+' with outliers')
    plt.xlabel(feature)
    plt.show()
# Out:
# sd Range of  normalized-losses :  10.0  to  234.0
# There are 1 sd outliers in  normalized-losses
# [256.0]
# C:\Users\manis\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# sd Range of  wheel-base :  82.65  to  114.25
# There are 3 sd outliers in  wheel-base
# [115.6, 115.6, 120.9]
# C:\Users\manis\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# sd Range of  length :  141.1  to  208.3
# ...

# %% [markdown]
# ### Lets see the categorical features now

# %%
0cat_feature = [feature for feature in df.columns if df[feature].dtype=='O']
print('There are {} categorical features in dataset..'.format(len(cat_feature)))
cat_feature
# Out:
# There are 10 categorical features in dataset..
# ['make',
#  'fuel-type',
#  'aspiration',
#  'num-of-doors',
#  'body-style',
#  'drive-wheels',
#  'engine-location',
#  'engine-type',
#  'num-of-cylinders',
#  'fuel-system']

# %%
df[cat_feature].head(10)
# Out:
#           make fuel-type aspiration num-of-doors   body-style drive-wheels  \
# 0  alfa-romero       gas        std          two  convertible          rwd
# 1  alfa-romero       gas        std          two  convertible          rwd
# 2  alfa-romero       gas        std          two    hatchback          rwd
# 3         audi       gas        std         four        sedan          fwd
# 4         audi       gas        std         four        sedan          4wd
# 5         audi       gas        std          two        sedan          fwd
# 6         audi       gas        std         four        sedan          fwd
# 7         audi       gas        std         four        wagon          fwd
# 8         audi       gas      turbo         four        sedan          fwd
# 9         audi       gas      turbo          two    hatchback          4wd
#
#   engine-location engine-type num-of-cylinders fuel-system
# 0           front        dohc             four        mpfi
# ...

# %%
for feature in cat_feature:
    print(feature,' has {} unique values'.format(len(df[feature].unique())))
    print(df[feature].unique())
    print('\n')
# Out:
# make  has 22 unique values
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
#
#
# fuel-type  has 2 unique values
# ['gas' 'diesel']
#
#
# aspiration  has 2 unique values
# ['std' 'turbo']
#
#
# num-of-doors  has 3 unique values
# ['two' 'four' nan]
#
#
# body-style  has 5 unique values
# ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
#
#
# drive-wheels  has 3 unique values
# ['rwd' 'fwd' '4wd']
#
#
# engine-location  has 2 unique values
# ['front' 'rear']
#
#
# engine-type  has 7 unique values
# ['dohc' 'ohcv' 'ohc' 'l' 'rotor' 'ohcf' 'dohcv']
#
#
# num-of-cylinders  has 7 unique values
# ['four' 'six' 'five' 'three' 'twelve' 'two' 'eight']
#
#
# fuel-system  has 8 unique values
# ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']

# %%
for feature in cat_feature:
    df.groupby(feature)['price'].mean().plot.bar(color='green')
    plt.title(feature)
    plt.xlabel(feature)
    plt.ylabel('price')
    plt.show()

# %% [markdown]
# ### Lets see overall distribution

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.528667   -0.531954 -0.357612
# normalized-losses   0.528667           1.000000   -0.074362  0.023220
# wheel-base         -0.531954          -0.074362    1.000000  0.874587
# length             -0.357612           0.023220    0.874587  1.000000
# width              -0.232919           0.105073    0.795144  0.841118
# height             -0.541038          -0.432335    0.589435  0.491029
# curb-weight        -0.227691           0.119893    0.776386  0.877728
# engine-size        -0.105790           0.167365    0.569329  0.683360
# bore               -0.134205          -0.036167    0.490378  0.607480
# stroke             -0.008965           0.065627    0.161477  0.129739
# compression-ratio  -0.178515          -0.132654    0.249786  0.158414
# horsepower          0.071622           0.295772    0.352297  0.555003
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(df.corr(), cmap='BuGn', annot=True)
# Out:
# <AxesSubplot:>
